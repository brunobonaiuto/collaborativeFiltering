# %%
import pandas as pd

data = {
    'Model': [1, 2, 3, 4, 5,6],
    'Train_loss': [0.134415, 0.181655, 0.264541, 0.354673, 0.37833, 0.306723],
    'Valid_loss': [0.236329, 0.553774, 1.276186, 1.37717, 1.486687, 1.585832],
    'MSE': [0.236329, 0.553774, 1.276186, 1.37717, 1.486687, 1.585832],
    'RMSE': [0.486136, 0.74416, 1.129684, 1.173529, 1.219298, 1.259298],
    'MAE': [0.268503, 0.429057, 0.914164, 0.941417, 0.95151, 1.011313],
    'Accuracy': [79, 67.43, 34.83, 31.93, 32.54, 27.89],
    'Dataset': ['df_oversamling.csv', 'upsampled_df_smote_auto.csv', 'merged_df.csv', 'downsampled_df_random.csv', 'df_under.csv', 'upsampled_df_smote.csv']
}

metrics_df = pd.DataFrame(data)
metrics_df
# Out:
#    Model  Train_loss  Valid_loss       MSE      RMSE       MAE  Accuracy  \
# 0      1    0.134415    0.236329  0.236329  0.486136  0.268503     79.00
# 1      2    0.181655    0.553774  0.553774  0.744160  0.429057     67.43
# 2      3    0.264541    1.276186  1.276186  1.129684  0.914164     34.83
# 3      4    0.354673    1.377170  1.377170  1.173529  0.941417     31.93
# 4      5    0.378330    1.486687  1.486687  1.219298  0.951510     32.54
# 5      6    0.306723    1.585832  1.585832  1.259298  1.011313     27.89
#
#                        Dataset
# 0           df_oversamling.csv
# 1  upsampled_df_smote_auto.csv
# 2                merged_df.csv
# 3    downsampled_df_random.csv
# 4                 df_under.csv
# 5       upsampled_df_smote.csv

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MAE'], marker='s', linestyle='-', label='MAE')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MSE'], marker='^', linestyle='-', label='MSE')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MAE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MSE'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Train_loss'], marker='s', linestyle='-', label='Train_loss')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Valid_loss'], marker='^', linestyle='-', label='Valid_loss')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Train_loss'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Valid_loss'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot Accuracy with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Accuracy'], marker='o', linestyle='-', label='Accuracy')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Accuracy'].iloc[i]))

# Set title and labels
plt.title('Accuracy for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Accuracy')

# Add a legend
plt.legend()

# Show the plot
plt.show()
