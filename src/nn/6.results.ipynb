# %%
import pandas as pd

data = {
    'Model': [1, 2, 3, 4, 5],
    'RMSE': [1.259298, 0.486136, 1.219298, 1.173529, 1.129684],
    'MAE': [1.011313, 0.268503, 0.95151, 0.941417, 0.914164],
    'MSE': [1.585832, 0.236329, 1.486687, 1.37717, 1.276186],
    'Train_loss': [0.306723, 0.134415, 0.37833, 0.354673, 0.264541],
    'Valid_loss': [1.585832, 0.236329, 1.486687, 1.37717, 1.276186],
    'Accuracy': [23.68, 79.00, 32.54, 31.93, 34.83],
    'Technique': ['SMOTE (Oversampling)', 'Oversampling', 'Undersampling', 'Undersampling', 'full_data'],
    'Dataset': ['upsampled_df_smote.csv', 'df_oversamling.csv', 'df_under.csv', 'downsampled_df_random.csv', 'merged_df.csv']
}

metrics_df = pd.DataFrame(data)
metrics_df
# Out:
#    Model      RMSE       MAE       MSE  Train_loss  Valid_loss  Accuracy  \
# 0      1  1.259298  1.011313  1.585832    0.306723    1.585832     23.68
# 1      2  0.486136  0.268503  0.236329    0.134415    0.236329     79.00
# 2      3  1.219298  0.951510  1.486687    0.378330    1.486687     32.54
# 3      4  1.173529  0.941417  1.377170    0.354673    1.377170     31.93
# 4      5  1.129684  0.914164  1.276186    0.264541    1.276186     34.83
#
#               Technique                    Dataset
# 0  SMOTE (Oversampling)     upsampled_df_smote.csv
# 1          Oversampling         df_oversamling.csv
# 2         Undersampling               df_under.csv
# 3         Undersampling  downsampled_df_random.csv
# 4             full_data              merged_df.csv

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MAE'], marker='s', linestyle='-', label='MAE')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MSE'], marker='^', linestyle='-', label='MSE')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MAE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MSE'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Train_loss'], marker='s', linestyle='-', label='Train_loss')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Valid_loss'], marker='^', linestyle='-', label='Valid_loss')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Train_loss'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Valid_loss'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot Accuracy with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Accuracy'], marker='o', linestyle='-', label='Accuracy')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Accuracy'].iloc[i]))

# Set title and labels
plt.title('Accuracy for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Accuracy')

# Add a legend
plt.legend()

# Show the plot
plt.show()
