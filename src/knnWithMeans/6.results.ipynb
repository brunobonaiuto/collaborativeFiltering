# %%
import pandas as pd
																																																
data = {
    'Model': ['1','1_cv','2','2_cv','3','3_cv','4','4_cv','5','5_cv'],
    'RMSE': [ 1.322879,0.142871,0.963988,0.166186,0.529036,0.179753,0.867394,0.185397,0.861790,0.179152],
    'MAE': [ 0.989803,0.027270,0.801028,0.032976,0.261286,0.042777,0.684785,0.036047,0.701743,0.043549],
    'MSE': [ 1.750010,0.020412,0.929274,0.027618,0.279879,0.032311,0.752372,0.034372,0.742682,0.032095],
    'Precision': [0.090535,0.760240,0.686700,0.760369,0.392857,0.829351,0.680044,0.802006,0.646180,0.801465],
    'Recall': [0.070165,0.740209,0.716749,0.737914,0.337328,0.797059,0.743421,0.796827,0.692300,0.777895],
    'Accuracy': [31.413613,97.796432,36.220472,97.147385,77.427822,97.480315,50.420168,97.310924,47.029703,96.329365],
    'Dataset': ['upsampled_df_smote.csv','upsampled_df_smote.csv', 'df_under.csv','df_under.csv','df_oversamling.csv','df_oversamling.csv', 'downsampled_df_random.csv', 'downsampled_df_random.csv', 'merged_df.csv', 'merged_df.csv']
}

metrics_df = pd.DataFrame(data)
metrics_df
# Out:
#   Model      RMSE       MAE       MSE  Precision    Recall   Accuracy  \
# 0     1  1.322879  0.989803  1.750010   0.090535  0.070165  31.413613
# 1  1_cv  0.142871  0.027270  0.020412   0.760240  0.740209  97.796432
# 2     2  0.963988  0.801028  0.929274   0.686700  0.716749  36.220472
# 3  2_cv  0.166186  0.032976  0.027618   0.760369  0.737914  97.147385
# 4     3  0.529036  0.261286  0.279879   0.392857  0.337328  77.427822
# 5  3_cv  0.179753  0.042777  0.032311   0.829351  0.797059  97.480315
# 6     4  0.867394  0.684785  0.752372   0.680044  0.743421  50.420168
# 7  4_cv  0.185397  0.036047  0.034372   0.802006  0.796827  97.310924
# 8     5  0.861790  0.701743  0.742682   0.646180  0.692300  47.029703
# 9  5_cv  0.179152  0.043549  0.032095   0.801465  0.777895  96.329365
#
#                      Dataset
# 0     upsampled_df_smote.csv
# 1     upsampled_df_smote.csv
# 2               df_under.csv
# 3               df_under.csv
# 4         df_oversamling.csv
# 5         df_oversamling.csv
# 6  downsampled_df_random.csv
# 7  downsampled_df_random.csv
# 8              merged_df.csv
# 9              merged_df.csv

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MAE'], marker='s', linestyle='-', label='MAE')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['MSE'], marker='^', linestyle='-', label='MSE')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MAE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['MSE'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot RMSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['RMSE'], marker='o', linestyle='-', label='RMSE')

# Plot MAE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Precision'], marker='s', linestyle='-', label='Precision')

# Plot MSE with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Recall'], marker='^', linestyle='-', label='Recall')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['RMSE'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Precision'].iloc[i]))
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Recall'].iloc[i]))

# Set title and labels
plt.title('Error Metrics for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Error Value')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot Accuracy with lines and points
plt.plot(range(metrics_df.shape[0]), metrics_df['Accuracy'], marker='o', linestyle='-', label='Accuracy')

# Annotate points with 'Index' column values
for i in range(metrics_df.shape[0]):
    plt.annotate(metrics_df['Model'].iloc[i], (i, metrics_df['Accuracy'].iloc[i]))

# Set title and labels
plt.title('Accuracy for Different Models')
plt.xlabel('Model Index')
plt.ylabel('Accuracy')

# Add a legend
plt.legend()

# Show the plot
plt.show()
