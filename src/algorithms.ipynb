# %%
from algorithms import *

import warnings

# Ignore the specific FutureWarning
warnings.filterwarnings('ignore')

# Your existing code...

metrics_df = pd.DataFrame(
    columns=['Model','Metric','Optimizer','User_based', 'k',
                'RMSE','MAE','MSE', 'Precision', 'Recall', 'Accuracy'])
# data set
data = pd.read_csv('/home/bbruno/all_here/python course/vinnie/data/cleaned_data/upsampled_df_smote_auto.csv')

for algorithm_class in [KNNBasic,KNNWithMeans]:
    for sim in ['cosine', 'msd', 'pearson', 'pearson_baseline']:
        for user_based in [True, False]:
            for bls in ['sgd', 'als']:
                for k in [5, 10]:
                    algo = {'algorithm_class': algorithm_class, 'k': k, 'sim_options': {'name': sim,'user_based': user_based}, 
                            'bsl_options':{'method': bls, 'learning_rate': 0.05, 'n_epochs':60, 'reg_u': 12 , 'reg_i': 5}}
                
                    print(f"algorithm: {algo['algorithm_class']}")
                    algorithms_instance = DynamicAlgo(**algo)
                    algorithms_instance.create_reader(data)
                    predictions = algorithms_instance.fit()
                    algorithms_instance.get_accuracy(predictions)
                
                    # metrics
                    metrics = algorithms_instance.get_accuracy(predictions)
                    
                    metrics['Model'] = algo['algorithm_class'].__name__.split('.')[-1]
                    metrics['Metric'] = sim
                    metrics['Optimizer'] = bls
                    # Ensure 'User_based' in metrics is of type bool
                    metrics['User_based'] = bool(user_based)
                    metrics['k'] = k
                    
                    # Append the dictionary to the existing DataFrame
                    metrics_df = pd.concat([metrics_df, pd.DataFrame(metrics, index=[0])], ignore_index=True)

# metrics_df.sort_values(by='RMSE', ascending=True, inplace=True)
metrics_df
# Out:
# algorithms.py was imported!
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1741
# RMSE: 0.7303
# RMSE on Training Set: 0.17406031954676093
# RMSE on Test Set: 0.7302627567801708
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7303
# MAE:  0.3885
# MSE: 0.5333
# Precision: 0.15
# Recall: 0.10
# the acc is 69.73
# RMSE: 0.7303
# MAE:  0.3885
# MSE: 0.5333
# Precision: 0.15
# Recall: 0.10
# the acc is 69.73
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1612
# RMSE: 0.7462
# RMSE on Training Set: 0.16124484613118084
# RMSE on Test Set: 0.7461928886576926
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7462
# MAE:  0.3979
# MSE: 0.5568
# Precision: 0.19
# Recall: 0.13
# the acc is 69.35
# RMSE: 0.7462
# MAE:  0.3979
# MSE: 0.5568
# Precision: 0.19
# Recall: 0.13
# the acc is 69.35
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1654
# RMSE: 0.7159
# RMSE on Training Set: 0.16543957112452495
# RMSE on Test Set: 0.7158706086891397
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7159
# MAE:  0.3954
# MSE: 0.5125
# Precision: 0.14
# Recall: 0.10
# the acc is 67.82
# RMSE: 0.7159
# MAE:  0.3954
# MSE: 0.5125
# Precision: 0.14
# Recall: 0.10
# the acc is 67.82
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1376
# RMSE: 0.9226
# RMSE on Training Set: 0.13755507370071493
# RMSE on Test Set: 0.9225861626523392
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.9226
# MAE:  0.5419
# MSE: 0.8512
# Precision: 0.16
# Recall: 0.09
# the acc is 60.54
# RMSE: 0.9226
# MAE:  0.5419
# MSE: 0.8512
# Precision: 0.16
# Recall: 0.09
# the acc is 60.54
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1682
# RMSE: 0.7802
# RMSE on Training Set: 0.1681865795399645
# RMSE on Test Set: 0.7801910081643014
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7802
# MAE:  0.4291
# MSE: 0.6087
# Precision: 0.17
# Recall: 0.13
# the acc is 66.67
# RMSE: 0.7802
# MAE:  0.4291
# MSE: 0.6087
# Precision: 0.17
# Recall: 0.13
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1533
# RMSE: 0.8043
# RMSE on Training Set: 0.15330510861906402
# RMSE on Test Set: 0.8042652304435591
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8043
# MAE:  0.4469
# MSE: 0.6468
# Precision: 0.15
# Recall: 0.12
# the acc is 65.13
# RMSE: 0.8043
# MAE:  0.4469
# MSE: 0.6468
# Precision: 0.15
# Recall: 0.12
# the acc is 65.13
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1461
# RMSE: 0.7066
# RMSE on Training Set: 0.14614547189675703
# RMSE on Test Set: 0.7066396888692464
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7066
# MAE:  0.3590
# MSE: 0.4993
# Precision: 0.12
# Recall: 0.09
# the acc is 70.50
# RMSE: 0.7066
# MAE:  0.3590
# MSE: 0.4993
# Precision: 0.12
# Recall: 0.09
# the acc is 70.50
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1588
# RMSE: 0.8449
# RMSE on Training Set: 0.15883046190896996
# RMSE on Test Set: 0.8448688752824742
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8449
# MAE:  0.4965
# MSE: 0.7138
# Precision: 0.19
# Recall: 0.14
# the acc is 62.45
# RMSE: 0.8449
# MAE:  0.4965
# MSE: 0.7138
# Precision: 0.19
# Recall: 0.14
# the acc is 62.45
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1320
# RMSE: 0.8279
# RMSE on Training Set: 0.13199471601040685
# RMSE on Test Set: 0.8279074093394151
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8279
# MAE:  0.4797
# MSE: 0.6854
# Precision: 0.14
# Recall: 0.09
# the acc is 62.07
# RMSE: 0.8279
# MAE:  0.4797
# MSE: 0.6854
# Precision: 0.14
# Recall: 0.09
# the acc is 62.07
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1618
# RMSE: 0.7161
# RMSE on Training Set: 0.161849566052472
# RMSE on Test Set: 0.7160785984847234
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7161
# MAE:  0.3783
# MSE: 0.5128
# Precision: 0.19
# Recall: 0.17
# the acc is 69.35
# RMSE: 0.7161
# MAE:  0.3783
# MSE: 0.5128
# Precision: 0.19
# Recall: 0.17
# the acc is 69.35
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1584
# RMSE: 0.8095
# RMSE on Training Set: 0.15842571129655753
# RMSE on Test Set: 0.809527447900135
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8095
# MAE:  0.4630
# MSE: 0.6553
# Precision: 0.16
# Recall: 0.11
# the acc is 64.37
# RMSE: 0.8095
# MAE:  0.4630
# MSE: 0.6553
# Precision: 0.16
# Recall: 0.11
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1598
# RMSE: 0.7990
# RMSE on Training Set: 0.15981936227854168
# RMSE on Test Set: 0.79899695733887
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7990
# MAE:  0.4581
# MSE: 0.6384
# Precision: 0.16
# Recall: 0.12
# the acc is 64.75
# RMSE: 0.7990
# MAE:  0.4581
# MSE: 0.6384
# Precision: 0.16
# Recall: 0.12
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1535
# RMSE: 0.7471
# RMSE on Training Set: 0.15354342131501647
# RMSE on Test Set: 0.7470845517642062
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7471
# MAE:  0.4105
# MSE: 0.5581
# Precision: 0.20
# Recall: 0.16
# the acc is 67.82
# RMSE: 0.7471
# MAE:  0.4105
# MSE: 0.5581
# Precision: 0.20
# Recall: 0.16
# the acc is 67.82
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1352
# RMSE: 0.8670
# RMSE on Training Set: 0.13515525220488606
# RMSE on Test Set: 0.8669921105000619
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8670
# MAE:  0.5093
# MSE: 0.7517
# Precision: 0.18
# Recall: 0.14
# the acc is 60.92
# RMSE: 0.8670
# MAE:  0.5093
# MSE: 0.7517
# Precision: 0.18
# Recall: 0.14
# the acc is 60.92
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1601
# RMSE: 0.8166
# RMSE on Training Set: 0.1601106415624422
# RMSE on Test Set: 0.8165716742501068
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8166
# MAE:  0.4649
# MSE: 0.6668
# Precision: 0.17
# Recall: 0.12
# the acc is 64.37
# RMSE: 0.8166
# MAE:  0.4649
# MSE: 0.6668
# Precision: 0.17
# Recall: 0.12
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1389
# RMSE: 0.7973
# RMSE on Training Set: 0.1389149797141637
# RMSE on Test Set: 0.7972646291013973
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7973
# MAE:  0.4466
# MSE: 0.6356
# Precision: 0.13
# Recall: 0.10
# the acc is 64.75
# RMSE: 0.7973
# MAE:  0.4466
# MSE: 0.6356
# Precision: 0.13
# Recall: 0.10
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1749
# RMSE: 0.7479
# RMSE on Training Set: 0.17489475503969762
# RMSE on Test Set: 0.7479083424498298
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7479
# MAE:  0.4104
# MSE: 0.5594
# Precision: 0.14
# Recall: 0.09
# the acc is 67.82
# RMSE: 0.7479
# MAE:  0.4104
# MSE: 0.5594
# Precision: 0.14
# Recall: 0.09
# the acc is 67.82
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1652
# RMSE: 0.8226
# RMSE on Training Set: 0.16521212823399037
# RMSE on Test Set: 0.8225661660422225
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8226
# MAE:  0.4656
# MSE: 0.6766
# Precision: 0.17
# Recall: 0.13
# the acc is 64.75
# RMSE: 0.8226
# MAE:  0.4656
# MSE: 0.6766
# Precision: 0.17
# Recall: 0.13
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1663
# RMSE: 0.7643
# RMSE on Training Set: 0.16626910578452536
# RMSE on Test Set: 0.7642668452861574
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7643
# MAE:  0.4214
# MSE: 0.5841
# Precision: 0.15
# Recall: 0.12
# the acc is 66.67
# RMSE: 0.7643
# MAE:  0.4214
# MSE: 0.5841
# Precision: 0.15
# Recall: 0.12
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1634
# RMSE: 0.7743
# RMSE on Training Set: 0.16343205166075445
# RMSE on Test Set: 0.7742617894377559
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7743
# MAE:  0.4565
# MSE: 0.5995
# Precision: 0.13
# Recall: 0.08
# the acc is 61.69
# RMSE: 0.7743
# MAE:  0.4565
# MSE: 0.5995
# Precision: 0.13
# Recall: 0.08
# the acc is 61.69
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1681
# RMSE: 0.8162
# RMSE on Training Set: 0.16811108276189496
# RMSE on Test Set: 0.8162228807434888
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8162
# MAE:  0.4613
# MSE: 0.6662
# Precision: 0.12
# Recall: 0.07
# the acc is 64.37
# RMSE: 0.8162
# MAE:  0.4613
# MSE: 0.6662
# Precision: 0.12
# Recall: 0.07
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1695
# RMSE: 0.6766
# RMSE on Training Set: 0.16946669617539323
# RMSE on Test Set: 0.6766499718468628
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.6766
# MAE:  0.3581
# MSE: 0.4579
# Precision: 0.16
# Recall: 0.10
# the acc is 70.50
# RMSE: 0.6766
# MAE:  0.3581
# MSE: 0.4579
# Precision: 0.16
# Recall: 0.10
# the acc is 70.50
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1482
# RMSE: 0.7757
# RMSE on Training Set: 0.1482007737036281
# RMSE on Test Set: 0.7756517277148323
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7757
# MAE:  0.4289
# MSE: 0.6016
# Precision: 0.15
# Recall: 0.10
# the acc is 65.90
# RMSE: 0.7757
# MAE:  0.4289
# MSE: 0.6016
# Precision: 0.15
# Recall: 0.10
# the acc is 65.90
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1339
# RMSE: 0.8313
# RMSE on Training Set: 0.13392619045960208
# RMSE on Test Set: 0.8312682010684926
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8313
# MAE:  0.4898
# MSE: 0.6910
# Precision: 0.15
# Recall: 0.10
# the acc is 62.45
# RMSE: 0.8313
# MAE:  0.4898
# MSE: 0.6910
# Precision: 0.15
# Recall: 0.10
# the acc is 62.45
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1677
# RMSE: 0.7420
# RMSE on Training Set: 0.16768360154110412
# RMSE on Test Set: 0.742013574120102
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7420
# MAE:  0.4197
# MSE: 0.5506
# Precision: 0.20
# Recall: 0.16
# the acc is 66.67
# RMSE: 0.7420
# MAE:  0.4197
# MSE: 0.5506
# Precision: 0.20
# Recall: 0.16
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1636
# RMSE: 0.7643
# RMSE on Training Set: 0.16361937015496827
# RMSE on Test Set: 0.7643099635025075
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7643
# MAE:  0.4144
# MSE: 0.5842
# Precision: 0.15
# Recall: 0.11
# the acc is 68.58
# RMSE: 0.7643
# MAE:  0.4144
# MSE: 0.5842
# Precision: 0.15
# Recall: 0.11
# the acc is 68.58
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1490
# RMSE: 0.8215
# RMSE on Training Set: 0.14895950400894947
# RMSE on Test Set: 0.8214924654693271
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8215
# MAE:  0.4622
# MSE: 0.6748
# Precision: 0.19
# Recall: 0.13
# the acc is 65.13
# RMSE: 0.8215
# MAE:  0.4622
# MSE: 0.6748
# Precision: 0.19
# Recall: 0.13
# the acc is 65.13
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1612
# RMSE: 0.7413
# RMSE on Training Set: 0.16121420394387176
# RMSE on Test Set: 0.741310637418285
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7413
# MAE:  0.4169
# MSE: 0.5495
# Precision: 0.17
# Recall: 0.13
# the acc is 67.05
# RMSE: 0.7413
# MAE:  0.4169
# MSE: 0.5495
# Precision: 0.17
# Recall: 0.13
# the acc is 67.05
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1418
# RMSE: 0.7782
# RMSE on Training Set: 0.1418301318030097
# RMSE on Test Set: 0.778220944170425
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7782
# MAE:  0.4280
# MSE: 0.6056
# Precision: 0.14
# Recall: 0.10
# the acc is 65.90
# RMSE: 0.7782
# MAE:  0.4280
# MSE: 0.6056
# Precision: 0.14
# Recall: 0.10
# the acc is 65.90
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1421
# RMSE: 0.7869
# RMSE on Training Set: 0.1421085639015305
# RMSE on Test Set: 0.7868599025740284
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7869
# MAE:  0.4197
# MSE: 0.6191
# Precision: 0.15
# Recall: 0.11
# the acc is 68.20
# RMSE: 0.7869
# MAE:  0.4197
# MSE: 0.6191
# Precision: 0.15
# Recall: 0.11
# the acc is 68.20
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1598
# RMSE: 0.7055
# RMSE on Training Set: 0.1597660438765195
# RMSE on Test Set: 0.7054835554958085
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7055
# MAE:  0.3784
# MSE: 0.4977
# Precision: 0.19
# Recall: 0.14
# the acc is 69.35
# RMSE: 0.7055
# MAE:  0.3784
# MSE: 0.4977
# Precision: 0.19
# Recall: 0.14
# the acc is 69.35
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNBasic'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1312
# RMSE: 0.8449
# RMSE on Training Set: 0.13115788544305376
# RMSE on Test Set: 0.8449448554752512
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8449
# MAE:  0.4827
# MSE: 0.7139
# Precision: 0.11
# Recall: 0.08
# the acc is 62.84
# RMSE: 0.8449
# MAE:  0.4827
# MSE: 0.7139
# Precision: 0.11
# Recall: 0.08
# the acc is 62.84
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2042
# RMSE: 0.8609
# RMSE on Training Set: 0.20422039109637402
# RMSE on Test Set: 0.8608986529568473
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8609
# MAE:  0.5007
# MSE: 0.7411
# Precision: 0.24
# Recall: 0.20
# the acc is 63.60
# RMSE: 0.8609
# MAE:  0.5007
# MSE: 0.7411
# Precision: 0.24
# Recall: 0.20
# the acc is 63.60
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2149
# RMSE: 0.7513
# RMSE on Training Set: 0.2148973129494611
# RMSE on Test Set: 0.7513338664204805
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7513
# MAE:  0.4181
# MSE: 0.5645
# Precision: 0.18
# Recall: 0.15
# the acc is 66.28
# RMSE: 0.7513
# MAE:  0.4181
# MSE: 0.5645
# Precision: 0.18
# Recall: 0.15
# the acc is 66.28
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2264
# RMSE: 0.7176
# RMSE on Training Set: 0.22636369848143534
# RMSE on Test Set: 0.7175840199135975
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7176
# MAE:  0.3894
# MSE: 0.5149
# Precision: 0.21
# Recall: 0.16
# the acc is 69.73
# RMSE: 0.7176
# MAE:  0.3894
# MSE: 0.5149
# Precision: 0.21
# Recall: 0.16
# the acc is 69.73
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2167
# RMSE: 0.8182
# RMSE on Training Set: 0.2166576207302567
# RMSE on Test Set: 0.8181725595462271
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8182
# MAE:  0.4802
# MSE: 0.6694
# Precision: 0.18
# Recall: 0.14
# the acc is 64.37
# RMSE: 0.8182
# MAE:  0.4802
# MSE: 0.6694
# Precision: 0.18
# Recall: 0.14
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2144
# RMSE: 0.7779
# RMSE on Training Set: 0.21439285225820146
# RMSE on Test Set: 0.7779133877604767
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7779
# MAE:  0.4548
# MSE: 0.6051
# Precision: 0.23
# Recall: 0.18
# the acc is 63.60
# RMSE: 0.7779
# MAE:  0.4548
# MSE: 0.6051
# Precision: 0.23
# Recall: 0.18
# the acc is 63.60
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1998
# RMSE: 0.7314
# RMSE on Training Set: 0.1998360874598276
# RMSE on Test Set: 0.7314388896936055
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7314
# MAE:  0.4007
# MSE: 0.5350
# Precision: 0.26
# Recall: 0.22
# the acc is 68.97
# RMSE: 0.7314
# MAE:  0.4007
# MSE: 0.5350
# Precision: 0.26
# Recall: 0.22
# the acc is 68.97
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2246
# RMSE: 0.8155
# RMSE on Training Set: 0.2246295040940978
# RMSE on Test Set: 0.8155358262773135
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8155
# MAE:  0.4986
# MSE: 0.6651
# Precision: 0.18
# Recall: 0.15
# the acc is 62.45
# RMSE: 0.8155
# MAE:  0.4986
# MSE: 0.6651
# Precision: 0.18
# Recall: 0.15
# the acc is 62.45
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2176
# RMSE: 0.7826
# RMSE on Training Set: 0.21757501642326843
# RMSE on Test Set: 0.7825538995299437
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7826
# MAE:  0.4667
# MSE: 0.6124
# Precision: 0.16
# Recall: 0.11
# the acc is 64.75
# RMSE: 0.7826
# MAE:  0.4667
# MSE: 0.6124
# Precision: 0.16
# Recall: 0.11
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2160
# RMSE: 0.8076
# RMSE on Training Set: 0.21601559644213028
# RMSE on Test Set: 0.8076217128230524
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8076
# MAE:  0.4695
# MSE: 0.6523
# Precision: 0.14
# Recall: 0.11
# the acc is 64.75
# RMSE: 0.8076
# MAE:  0.4695
# MSE: 0.6523
# Precision: 0.14
# Recall: 0.11
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2146
# RMSE: 0.7803
# RMSE on Training Set: 0.21461360725109457
# RMSE on Test Set: 0.7802972199337983
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7803
# MAE:  0.4567
# MSE: 0.6089
# Precision: 0.14
# Recall: 0.11
# the acc is 63.98
# RMSE: 0.7803
# MAE:  0.4567
# MSE: 0.6089
# Precision: 0.14
# Recall: 0.11
# the acc is 63.98
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2263
# RMSE: 0.8065
# RMSE on Training Set: 0.22630039706773192
# RMSE on Test Set: 0.806451986774119
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8065
# MAE:  0.4731
# MSE: 0.6504
# Precision: 0.17
# Recall: 0.14
# the acc is 64.37
# RMSE: 0.8065
# MAE:  0.4731
# MSE: 0.6504
# Precision: 0.17
# Recall: 0.14
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2129
# RMSE: 0.7892
# RMSE on Training Set: 0.21288428428896142
# RMSE on Test Set: 0.7891584167353795
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7892
# MAE:  0.4817
# MSE: 0.6228
# Precision: 0.17
# Recall: 0.14
# the acc is 62.84
# RMSE: 0.7892
# MAE:  0.4817
# MSE: 0.6228
# Precision: 0.17
# Recall: 0.14
# the acc is 62.84
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2088
# RMSE: 0.8197
# RMSE on Training Set: 0.2088423488453206
# RMSE on Test Set: 0.8197252098258445
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8197
# MAE:  0.4826
# MSE: 0.6719
# Precision: 0.20
# Recall: 0.16
# the acc is 63.98
# RMSE: 0.8197
# MAE:  0.4826
# MSE: 0.6719
# Precision: 0.20
# Recall: 0.16
# the acc is 63.98
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2266
# RMSE: 0.7838
# RMSE on Training Set: 0.2265844670518508
# RMSE on Test Set: 0.7838477974810043
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7838
# MAE:  0.4741
# MSE: 0.6144
# Precision: 0.22
# Recall: 0.16
# the acc is 62.07
# RMSE: 0.7838
# MAE:  0.4741
# MSE: 0.6144
# Precision: 0.22
# Recall: 0.16
# the acc is 62.07
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2195
# RMSE: 0.8044
# RMSE on Training Set: 0.21949571580517577
# RMSE on Test Set: 0.8043985975123019
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8044
# MAE:  0.4318
# MSE: 0.6471
# Precision: 0.16
# Recall: 0.13
# the acc is 69.35
# RMSE: 0.8044
# MAE:  0.4318
# MSE: 0.6471
# Precision: 0.16
# Recall: 0.13
# the acc is 69.35
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1984
# RMSE: 0.8782
# RMSE on Training Set: 0.19840264653100892
# RMSE on Test Set: 0.8781606440746172
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8782
# MAE:  0.5327
# MSE: 0.7712
# Precision: 0.13
# Recall: 0.10
# the acc is 60.92
# RMSE: 0.8782
# MAE:  0.5327
# MSE: 0.7712
# Precision: 0.13
# Recall: 0.10
# the acc is 60.92
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2087
# RMSE: 0.8577
# RMSE on Training Set: 0.20871262607162006
# RMSE on Test Set: 0.8577380870496609
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8577
# MAE:  0.4945
# MSE: 0.7357
# Precision: 0.23
# Recall: 0.18
# the acc is 64.75
# RMSE: 0.8577
# MAE:  0.4945
# MSE: 0.7357
# Precision: 0.23
# Recall: 0.18
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2219
# RMSE: 0.7769
# RMSE on Training Set: 0.22188068645831405
# RMSE on Test Set: 0.7768571689879206
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7769
# MAE:  0.4364
# MSE: 0.6035
# Precision: 0.25
# Recall: 0.20
# the acc is 66.28
# RMSE: 0.7769
# MAE:  0.4364
# MSE: 0.6035
# Precision: 0.25
# Recall: 0.20
# the acc is 66.28
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2166
# RMSE: 0.8101
# RMSE on Training Set: 0.21662842215586475
# RMSE on Test Set: 0.8101120709944406
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8101
# MAE:  0.4634
# MSE: 0.6563
# Precision: 0.17
# Recall: 0.15
# the acc is 66.67
# RMSE: 0.8101
# MAE:  0.4634
# MSE: 0.6563
# Precision: 0.17
# Recall: 0.15
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2195
# RMSE: 0.7797
# RMSE on Training Set: 0.2195156943431041
# RMSE on Test Set: 0.7796768759930897
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7797
# MAE:  0.4438
# MSE: 0.6079
# Precision: 0.22
# Recall: 0.19
# the acc is 67.05
# RMSE: 0.7797
# MAE:  0.4438
# MSE: 0.6079
# Precision: 0.22
# Recall: 0.19
# the acc is 67.05
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2034
# RMSE: 0.7354
# RMSE on Training Set: 0.20342798725241168
# RMSE on Test Set: 0.7353645175926142
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7354
# MAE:  0.3833
# MSE: 0.5408
# Precision: 0.25
# Recall: 0.24
# the acc is 71.65
# RMSE: 0.7354
# MAE:  0.3833
# MSE: 0.5408
# Precision: 0.25
# Recall: 0.24
# the acc is 71.65
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2284
# RMSE: 0.7672
# RMSE on Training Set: 0.2283743769246408
# RMSE on Test Set: 0.7672482220856308
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7672
# MAE:  0.4319
# MSE: 0.5887
# Precision: 0.25
# Recall: 0.22
# the acc is 67.43
# RMSE: 0.7672
# MAE:  0.4319
# MSE: 0.5887
# Precision: 0.25
# Recall: 0.22
# the acc is 67.43
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2268
# RMSE: 0.8191
# RMSE on Training Set: 0.2267547387267051
# RMSE on Test Set: 0.8191395049652341
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8191
# MAE:  0.4617
# MSE: 0.6710
# Precision: 0.24
# Recall: 0.17
# the acc is 66.67
# RMSE: 0.8191
# MAE:  0.4617
# MSE: 0.6710
# Precision: 0.24
# Recall: 0.17
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2013
# RMSE: 0.7730
# RMSE on Training Set: 0.2012509171409828
# RMSE on Test Set: 0.7730499466775176
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7730
# MAE:  0.4383
# MSE: 0.5976
# Precision: 0.18
# Recall: 0.14
# the acc is 66.28
# RMSE: 0.7730
# MAE:  0.4383
# MSE: 0.5976
# Precision: 0.18
# Recall: 0.14
# the acc is 66.28
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2201
# RMSE: 0.8290
# RMSE on Training Set: 0.22008716744729245
# RMSE on Test Set: 0.8289631657211717
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8290
# MAE:  0.5139
# MSE: 0.6872
# Precision: 0.16
# Recall: 0.11
# the acc is 59.77
# RMSE: 0.8290
# MAE:  0.5139
# MSE: 0.6872
# Precision: 0.16
# Recall: 0.11
# the acc is 59.77
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2223
# RMSE: 0.7547
# RMSE on Training Set: 0.22227469801008454
# RMSE on Test Set: 0.7547114650047133
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7547
# MAE:  0.4417
# MSE: 0.5696
# Precision: 0.15
# Recall: 0.11
# the acc is 65.13
# RMSE: 0.7547
# MAE:  0.4417
# MSE: 0.5696
# Precision: 0.15
# Recall: 0.11
# the acc is 65.13
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2043
# RMSE: 0.8333
# RMSE on Training Set: 0.2043043263212618
# RMSE on Test Set: 0.8333233383793098
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8333
# MAE:  0.4952
# MSE: 0.6944
# Precision: 0.16
# Recall: 0.14
# the acc is 61.69
# RMSE: 0.8333
# MAE:  0.4952
# MSE: 0.6944
# Precision: 0.16
# Recall: 0.14
# the acc is 61.69
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2055
# RMSE: 0.7690
# RMSE on Training Set: 0.20550545031456857
# RMSE on Test Set: 0.7690091277197887
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.7690
# MAE:  0.4101
# MSE: 0.5914
# Precision: 0.15
# Recall: 0.13
# the acc is 69.35
# RMSE: 0.7690
# MAE:  0.4101
# MSE: 0.5914
# Precision: 0.15
# Recall: 0.13
# the acc is 69.35
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1717
# RMSE: 0.8465
# RMSE on Training Set: 0.17173730268356768
# RMSE on Test Set: 0.8465256771797101
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8465
# MAE:  0.4726
# MSE: 0.7166
# Precision: 0.19
# Recall: 0.17
# the acc is 64.75
# RMSE: 0.8465
# MAE:  0.4726
# MSE: 0.7166
# Precision: 0.19
# Recall: 0.17
# the acc is 64.75
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2208
# RMSE: 0.8150
# RMSE on Training Set: 0.220818554116084
# RMSE on Test Set: 0.8149683698286389
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8150
# MAE:  0.4923
# MSE: 0.6642
# Precision: 0.18
# Recall: 0.12
# the acc is 64.37
# RMSE: 0.8150
# MAE:  0.4923
# MSE: 0.6642
# Precision: 0.18
# Recall: 0.12
# the acc is 64.37
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2270
# RMSE: 0.8087
# RMSE on Training Set: 0.22695754987254202
# RMSE on Test Set: 0.8087462558454865
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8087
# MAE:  0.4604
# MSE: 0.6541
# Precision: 0.19
# Recall: 0.15
# the acc is 66.67
# RMSE: 0.8087
# MAE:  0.4604
# MSE: 0.6541
# Precision: 0.19
# Recall: 0.15
# the acc is 66.67
# algorithm: <class 'surprise.prediction_algorithms.knns.KNNWithMeans'>
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.1811
# RMSE: 0.8657
# RMSE on Training Set: 0.18111558114928963
# RMSE on Test Set: 0.8656549918129286
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# RMSE: 0.8657
# MAE:  0.4994
# MSE: 0.7494
# Precision: 0.19
# Recall: 0.16
# the acc is 62.07
# RMSE: 0.8657
# MAE:  0.4994
# MSE: 0.7494
# Precision: 0.19
# Recall: 0.16
# the acc is 62.07
#            Model            Metric Optimizer User_based   k      RMSE  \
# 0       KNNBasic            cosine       sgd       True   5  0.730263
# 1       KNNBasic            cosine       sgd       True  10  0.746193
# 2       KNNBasic            cosine       als       True   5  0.715871
# 3       KNNBasic            cosine       als       True  10  0.922586
# 4       KNNBasic            cosine       sgd      False   5  0.780191
# ..           ...               ...       ...        ...  ..       ...
# 59  KNNWithMeans  pearson_baseline       als       True  10  0.769009
# 60  KNNWithMeans  pearson_baseline       sgd      False   5  0.846526
# 61  KNNWithMeans  pearson_baseline       sgd      False  10  0.814968
# 62  KNNWithMeans  pearson_baseline       als      False   5  0.808746
# 63  KNNWithMeans  pearson_baseline       als      False  10  0.865655
#
#          MAE       MSE  Precision    Recall   Accuracy
# 0   0.388514  0.533284   0.145199  0.100729  69.731801
# 1   0.397864  0.556804   0.193155  0.130467  69.348659
# 2   0.395406  0.512471   0.139785  0.099225  67.816092
# 3   0.541933  0.851165   0.156250  0.089455  60.536398
# 4   0.429104  0.608698   0.173246  0.126441  66.666667
# ..       ...       ...        ...       ...        ...
# 59  0.410073  0.591375   0.148795  0.132496  69.348659
# 60  0.472623  0.716606   0.188304  0.169177  64.750958
# 61  0.492252  0.664173   0.175325  0.120527  64.367816
# 62  0.460357  0.654071   0.192727  0.150232  66.666667
# 63  0.499353  0.749359   0.192012  0.157543  62.068966
#
# [64 rows x 11 columns]

# %%
data = pd.read_csv('/home/bbruno/all_here/python course/vinnie/data/cleaned_data/upsampled_df_smote.csv')

knn_basic = DynamicAlgo(
        algorithm_class=KNNBasic, 
        k=5, 
        sim_options = {'name': 'pearson_baseline','user_based': False},
        bsl_options={'method': 'sgd', 'learning_rate': 0.05, 'n_epochs':60, 'reg_u': 12 , 'reg_i': 5})
    # algorithm methods
knn_basic.create_reader(data)
predictions = knn_basic.fit()
# algorithm methods
knn_basic.create_reader(data)
predictions = knn_basic.fit()

# %%
knn_basic.get_neighbors_uid(user_id=5)

# %%
knn_basic.get_neighbors_iid(item_id=5)

# %%
knn_basic.estimated(u=5, i=5)

# %%
df_pred = knn_basic.inspect_predictions(predictions)
best_pred = df_pred.sort_values(by='err')[:10]
worst_pred = df_pred.sort_values(by='err')[-10:]
df_pred.head()

# %%
knn_basic.get_accuracy(predictions)
